# %%
pip install "openai==0.28.1" num2words matplotlib plotly scipy scikit-learn pandas tiktoken
# Out:
# Requirement already satisfied: openai==0.28.1 in ./venv/lib/python3.10/site-packages (0.28.1)
# Requirement already satisfied: num2words in ./venv/lib/python3.10/site-packages (0.5.13)
# Requirement already satisfied: matplotlib in ./venv/lib/python3.10/site-packages (3.8.1)
# Requirement already satisfied: plotly in ./venv/lib/python3.10/site-packages (5.18.0)
# Requirement already satisfied: scipy in ./venv/lib/python3.10/site-packages (1.11.3)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: pandas in ./venv/lib/python3.10/site-packages (2.1.2)
# Requirement already satisfied: tiktoken in ./venv/lib/python3.10/site-packages (0.5.1)
# Requirement already satisfied: requests>=2.20 in ./venv/lib/python3.10/site-packages (from openai==0.28.1) (2.31.0)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.10/site-packages (from openai==0.28.1) (3.8.6)
# Requirement already satisfied: tqdm in ./venv/lib/python3.10/site-packages (from openai==0.28.1) (4.66.1)
# Requirement already satisfied: docopt>=0.6.2 in ./venv/lib/python3.10/site-packages (from num2words) (0.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=8 in ./venv/lib/python3.10/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (4.44.0)
# Requirement already satisfied: numpy<2,>=1.21 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.26.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.10/site-packages (from matplotlib) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.10/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in ./venv/lib/python3.10/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: joblib>=1.1.1 in ./venv/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv/lib/python3.10/site-packages (from scikit-learn) (3.2.0)
# Requirement already satisfied: tzdata>=2022.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: regex>=2022.1.18 in ./venv/lib/python3.10/site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.10/site-packages (from requests>=2.20->openai==0.28.1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv/lib/python3.10/site-packages (from requests>=2.20->openai==0.28.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.10/site-packages (from requests>=2.20->openai==0.28.1) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.10/site-packages (from requests>=2.20->openai==0.28.1) (3.3.2)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (23.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (1.9.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (6.0.4)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv/lib/python3.10/site-packages (from aiohttp->openai==0.28.1) (1.4.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import csv
import re

# %%
import re

def process_text(input_text):
    # Remove anything inside and including square brackets
    input_text = re.sub(r'\[.*?\]', '', input_text)

    # Remove double quotes
    input_text = input_text.replace('"', '')

    # Convert text to lowercase
    input_text = input_text.lower()

    # Remove extra whitespace in lines and join the remaining lines
    lines = input_text.split('\n')
    cleaned_lines = [re.sub(r'\s+', ' ', line.strip()) for line in lines]
    cleaned_text = ' '.join(cleaned_lines)

    return cleaned_text

def process_text_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        lines = file.readlines()
        # Remove the first line
        lines = lines[1:]

        # Join the remaining lines and remove extra whitespace
        lyrics = ' '.join([line.strip() for line in lines])

        #Remove extra whitespace in lines
        lyrics = re.sub(r'\s+',' ', lyrics)

        # Remove the last 5 characters
        lyrics = lyrics[:-5]

        # Convert text to lowercase
        lyrics = lyrics.lower()

        # Remove double quotes
        lyrics = lyrics.replace('"', '')

        # Remove anything inside and including square brackets
        lyrics = re.sub(r'\[.*?\]', '', lyrics)

        # Check and remove the first occurrence of a number and characters that follow in the last three characters
        lyrics = lyrics[:-3] + re.sub(r'\d.*$', '',lyrics[-3:])

        return lyrics

# %%
def create_csv_from_txt(root_directory, output_csv):
    with open(output_csv, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['album', 'songTitle', 'lyrics']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

        for album_name in os.listdir(root_directory):
            album_directory = os.path.join(root_directory, album_name)
            if os.path.isdir(album_directory):
                for song_file in os.listdir(album_directory):
                    # Remove the last 4 characters from the file name
                    song_title = song_file[:-4]
                    song_file = os.path.join(album_directory, song_file)
                    if os.path.isfile(song_file):
                        lyrics = process_text_file(song_file)
                        writer.writerow({'album': album_name, 'songTitle': song_title, 'lyrics': lyrics})

# %%
root_directory = '/Users/yorkmacbook018/PycharmProjects/pythonProject1/data/Albums'
output_csv = 'taylorLyrics.csv'
create_csv_from_txt(root_directory, output_csv)

# %%
import openai
import os
import re
import requests
import sys
from num2words import num2words
import os
import pandas as pd
import numpy as np
from openai.embeddings_utils import get_embedding, cosine_similarity
import tiktoken

API_KEY = os.getenv("AZURE_OPENAI_API_KEY") 
RESOURCE_ENDPOINT = os.getenv("AZURE_OPENAI_ENDPOINT") 

openai.api_type = "azure"
openai.api_key = API_KEY
openai.api_base = RESOURCE_ENDPOINT
openai.api_version = "2022-12-01"

url = openai.api_base + "/openai/deployments?api-version=2022-12-01" 

r = requests.get(url, headers={"api-key": API_KEY})

print(r.text)
# Out:
# {
#   "data": [
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "text-embedding-ada-002",
#       "owner": "organization-owner",
#       "id": "test-deployment",
#       "status": "succeeded",
#       "created_at": 1697552606,
#       "updated_at": 1697552606,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "gpt-35-turbo-16k",
#       "owner": "organization-owner",
#       "id": "gptDeployment",
#       "status": "succeeded",
#       "created_at": 1698762465,
#       "updated_at": 1698762465,
#       "object": "deployment"
#     },
#     {
#       "scale_settings": {
#         "scale_type": "standard"
#       },
#       "model": "gpt-35-turbo",
#       "owner": "organization-owner",
#       "id": "gptDeployTest",
#       "status": "succeeded",
#       "created_at": 1698783426,
#       "updated_at": 1698783426,
#       "object": "deployment"
#     }
#   ],
#   "object": "list"
# }

# %%
df=pd.read_csv(os.path.join(os.getcwd(),'taylorLyrics.csv'))
df
# Out:
#         album                                       songTitle  \
# 0       lover                            ItsNicetoHaveaFriend
# 1       lover                                             ME_
# 2       lover                                  CorneliaStreet
# 3       lover                               YouNeedToCalmDown
# 4       lover                                          TheMan
# ..        ...                                             ...
# 185  fearless                        Fearless_TaylorsVersion_
# 186  fearless               ComeInWithTheRain_TaylorsVersion_
# 187  fearless                      TheBestDay_TaylorsVersion_
# 188  fearless  Mr_PerfectlyFine_TaylorsVersion__FromtheVault_
# 189  fearless                          Change_TaylorsVersion_
#
#                                                 lyrics
# 0    ooh ooh  school bell rings, walk me home sidew...
# 1    i promise that you'll never find another like ...
# 2    we were in the backseat drunk on something str...
# 3    you are somebody that i don't know but you're ...
# 4    i would be complex, i would be cool they'd say...
# ..                                                 ...
# 185  there's something 'bout the way the street loo...
# 186  i could go back to every laugh but i don't wan...
# 187  i'm five years old, it's getting cold, i've go...
# 188  mr. perfect face mr. here to stay mr. looked m...
# 189  well, it's a sad picture, the final blow hits ...
#
# [190 rows x 3 columns]

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")
df['n_tokens'] = df["lyrics"].apply(lambda x: len(tokenizer.encode(x)))
df = df[df.n_tokens<8192]
len(df)
# Out:
# 190

# %%
df
# Out:
#         album                                       songTitle  \
# 0       lover                            ItsNicetoHaveaFriend
# 1       lover                                             ME_
# 2       lover                                  CorneliaStreet
# 3       lover                               YouNeedToCalmDown
# 4       lover                                          TheMan
# ..        ...                                             ...
# 185  fearless                        Fearless_TaylorsVersion_
# 186  fearless               ComeInWithTheRain_TaylorsVersion_
# 187  fearless                      TheBestDay_TaylorsVersion_
# 188  fearless  Mr_PerfectlyFine_TaylorsVersion__FromtheVault_
# 189  fearless                          Change_TaylorsVersion_
#
#                                                 lyrics  n_tokens
# 0    ooh ooh  school bell rings, walk me home sidew...       216
# 1    i promise that you'll never find another like ...       679
# 2    we were in the backseat drunk on something str...       468
# 3    you are somebody that i don't know but you're ...       510
# 4    i would be complex, i would be cool they'd say...       566
# ..                                                 ...       ...
# 185  there's something 'bout the way the street loo...       392
# 186  i could go back to every laugh but i don't wan...       270
# 187  i'm five years old, it's getting cold, i've go...       389
# 188  mr. perfect face mr. here to stay mr. looked m...       527
# 189  well, it's a sad picture, the final blow hits ...       349
#
# [190 rows x 4 columns]

# %%
df['ada_v2'] = df["lyrics"].apply(lambda x : get_embedding(x, engine = 'test-deployment'))
df
# Out:
#         album                                       songTitle  \
# 0       lover                            ItsNicetoHaveaFriend
# 1       lover                                             ME_
# 2       lover                                  CorneliaStreet
# 3       lover                               YouNeedToCalmDown
# 4       lover                                          TheMan
# ..        ...                                             ...
# 185  fearless                        Fearless_TaylorsVersion_
# 186  fearless               ComeInWithTheRain_TaylorsVersion_
# 187  fearless                      TheBestDay_TaylorsVersion_
# 188  fearless  Mr_PerfectlyFine_TaylorsVersion__FromtheVault_
# 189  fearless                          Change_TaylorsVersion_
#
#                                                 lyrics  n_tokens  \
# 0    ooh ooh  school bell rings, walk me home sidew...       216
# 1    i promise that you'll never find another like ...       679
# 2    we were in the backseat drunk on something str...       468
# 3    you are somebody that i don't know but you're ...       510
# 4    i would be complex, i would be cool they'd say...       566
# ..                                                 ...       ...
# 185  there's something 'bout the way the street loo...       392
# 186  i could go back to every laugh but i don't wan...       270
# 187  i'm five years old, it's getting cold, i've go...       389
# 188  mr. perfect face mr. here to stay mr. looked m...       527
# 189  well, it's a sad picture, the final blow hits ...       349
#
#                                                 ada_v2
# 0    [0.004287575837224722, 0.004665118642151356, 0...
# 1    [-0.03382572531700134, -0.018947692587971687, ...
# 2    [-0.0021139904856681824, -0.006929566152393818...
# 3    [-0.012121044099330902, -0.0057776314206421375...
# 4    [-0.02835487388074398, -0.011759167537093163, ...
# ..                                                 ...
# 185  [-0.01833091862499714, 0.010790827684104443, -...
# 186  [-0.01441550999879837, -0.014507664367556572, ...
# 187  [-0.007198348641395569, -0.013294247910380363,...
# 188  [-0.02875860407948494, -0.004770951345562935, ...
# 189  [-0.00860496237874031, -0.013732057996094227, ...
#
# [190 rows x 5 columns]

# %%
search_text = process_text("""[Intro: Sir Mix-a-Lot]
My anaconda don't
My anaconda don't
My anaconda don't want none
Unless you got buns, hun

[Verse 1: Nicki Minaj]
Boy toy named Troy
Used to live in Detroit
Bi-bi-big dope dealer money
He was gettin' some coins
        user_query,
        engine="test-deployment" # engine should be set to the deployment name you chose when you deployed the text-embedding-ada-002 (Version 2) model
    )
    df["similarities"] = df.ada_v2.apply(lambda x: cosine_similarity(x, embedding))

    res = (
        df.sort_values("similarities", ascending=False)
        .head(top_n)
    )
    if to_print:
        display(res[['songTitle', 'lyrics', 'similarities']])
    return res


res = search_songs(df, search_text, top_n=30)
# Out:
#                                  songTitle  \
# 91                                   Karma
# 56                            cowboylikeme
# 69                       CallItWhatYouWant
# 141                               madwoman
# 67                     LookWhatYouMadeMeDo
# 74                           KingofMyHeart
# 15                               LondonBoy
# 57                          longstoryshort
# 182              TellMeWhy_TaylorsVersion_
# 63                        IDidSomethingBad
# 66                             DontBlameMe
# 14                             CruelSummer
# 31                           PicturetoBurn
# 93                               Bejeweled
# 19                              BlankSpace
# 20                             IKnowPlaces
# 88                                   Paris
# 90                           VigilanteShit
# 23                           WildestDreams
# 153      BetterThanRevenge_TaylorsVersion_
# 167  DontYou_TaylorsVersion__FromtheVault_
# 9                                Afterglow
# 115             BeginAgain_TaylorsVersion_
# 54                                dorothea
# 149                   Mean_TaylorsVersion_
# 12                                Daylight
# 135                                   the1
# 123    IKnewYouWereTrouble_TaylorsVersion_
# 6                                TheArcher
# 77           ThisIsWhyWeCantHaveNiceThings
#
#                                                 lyrics  similarities
# 91   you're talking shit for the hell of it addicte...      0.798073
# 56   and the tennis court was covered up with some ...      0.794529
# 69   my castle crumbled overnight i brought a knife...      0.793868
# 141  what did you think i'd say to that? does a sco...      0.790485
# 67   i don't like your little games don't like your...      0.788922
# 74   i'm perfectly fine, i live on my own i made up...      0.787833
# 15   we can go drivin' in, on my scooter uh, you kn...      0.787741
# 57   fatefully i tried to pick my battles 'til the ...      0.785786
# 182  i took a chance, i took a shot and you might t...      0.785182
# 63   i never trust a narcissist, but they love me s...      0.784740
# 66   don't blame me, love made me crazy if it doesn...      0.784149
# 14   (yeah, yeah, yeah, yeah)  fever dream high in ...      0.784097
# 31   state the obvious, i didn't get my perfect fan...      0.784093
# 93   baby love, i think i've been a little too kind...      0.784070
# 19   nice to meet you, where you been? i could show...      0.783827
# 20    i, i, i, i, i, i, i, i-i i, i, i, i, i, i, i,...      0.782894
# 88   your ex-friend's sister met someone at a club ...      0.782793
# 90   draw the cat eye sharp enough to kill a man yo...      0.781569
# 23   he said, let's get out of this town drive out ...      0.781482
# 153  now go stand in the corner and think about wha...      0.780249
# 167  hey, i knew i'd run into you somewhere it's be...      0.779816
# 9    i blew things out of proportion, now you're bl...      0.779777
# 115  took a deep breath in the mirror he didn't lik...      0.779713
# 54   hey, dorothea, do you ever stop and think abou...      0.779527
# 149  you, with your words like knives and swords an...      0.779368
# 12   my love was as cruel as the cities i lived in ...      0.778610
# 135  i'm doing good, i'm on some new shit been sayi...      0.778150
# 123  once upon a time, a few mistakes ago i was in ...      0.777411
# 6    combat, i'm ready for combat i say i don't wan...      0.777149
# 77   it was so nice throwing big parties jump into ...      0.775750
